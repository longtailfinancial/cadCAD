# %%
import cadCAD

# %%
# !jupyter --version
# Out:
# jupyter core     : 4.7.1
# jupyter-notebook : 6.3.0
# qtconsole        : not installed
# ipython          : 7.21.0
# ipykernel        : 5.5.0
# jupyter client   : 6.1.12
# jupyter lab      : not installed
# nbconvert        : 6.0.7
# ipywidgets       : not installed
# nbformat         : 5.1.2
# traitlets        : 5.0.5

# %%
# !which pip
# Out:
# /home/jjodesty/Projects/Work/cadCAD-cs/venv/bin/pip

# %%
# !pip list
# Out:
# Package             Version
# ------------------- ---------
# argon2-cffi         20.1.0
# async-generator     1.10
# attrs               20.3.0
# backcall            0.2.0
# bleach              3.3.0
# cadCAD              0.4.24
# certifi             2020.12.5
# cffi                1.14.5
# chardet             4.0.0
# cycler              0.10.0
# decorator           4.4.2
# defusedxml          0.7.1
# dill                0.3.3
# entrypoints         0.3
# fn                  0.4.3
# funcy               1.14
# idna                2.10
# iniconfig           1.1.1
# ipykernel           5.5.0
# ipython             7.21.0
# ipython-genutils    0.2.0
# jedi                0.18.0
# Jinja2              2.11.3
# joblib              1.0.1
# jsonschema          3.2.0
# jupyter-client      6.1.12
# jupyter-core        4.7.1
# jupyterlab-pygments 0.1.2
# kiwisolver          1.3.1
# llvmlite            0.34.0
# MarkupSafe          1.1.1
# matplotlib          3.3.2
# mistune             0.8.4
# ...

# %%
import pandas as pd

from cadCAD.engine import ExecutionMode, ExecutionContext, Executor
from simulations.regression_tests.experiments import param_sweep_exp, combo_exp
from simulations.regression_tests.models import param_sweep

exec_mode = ExecutionMode()

local_proc_ctx = ExecutionContext(context=exec_mode.local_mode)
# run = Executor(exec_context=local_proc_ctx, configs=param_sweep_exp.configs) #empty_return=False
run = Executor(exec_context=local_proc_ctx, configs=combo_exp.configs) #empty_return=False
#
raw_result, tensor_fields, sessions = run.execute()
result = pd.DataFrame(raw_result)
# # print(tabulate(tensor_fields[0], headers='keys', tablefmt='psql'))
# # # pprint(sessions)
result
# Out:
#                   ___________    ____
#   ________ __ ___/ / ____/   |  / __ \
#  / ___/ __` / __  / /   / /| | / / / /
# / /__/ /_/ / /_/ / /___/ ___ |/ /_/ /
# \___/\__,_/\__,_/\____/_/  |_/_____/
# by cadCAD
#
# Execution Mode: local_proc
# Configuration Count: 1
# Dimensions of the first simulation: (Timesteps, Params, Runs, Vars) = (2, 4, 4, 4)
# Execution Method: local_simulations
# SimIDs   : [0, 0, 0, 0]
# SubsetIDs: [0, 0, 1, 1]
# Ns       : [0, 1, 0, 1]
# ExpIDs   : [0, 0, 0, 0]
# Execution Mode: parallelized
# Total execution time: 0.02s
#     alpha                                        beta  \
# 0       0                                           0
# 1       1                                           2
# 2       1                                           2
# 3       1                                           2
# 4       1                                           2
# 5       1                                           2
# ...
